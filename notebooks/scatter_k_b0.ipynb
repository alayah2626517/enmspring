# %%
import matplotlib.pyplot as plt
from enmspring.spring import Spring
from enmspring import k_b0_util
from enmspring.k_b0_plot import ScatterPlot

# %% [markdown]
# ### Part 0: Initialize

# %%
rootfolder = '/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm'
cutoff = 4.7
host = 'nome'
type_na = 'bdna+bdna'
n_bp = 13
spring_obj = Spring(rootfolder, host, type_na, n_bp)
# Out:
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/nome/bdna+bdna/pd_dfs exists

# %% [markdown]
# ### Part 1 : Process Data

# %%
df0 = spring_obj.read_k_b0_pairtype_df_given_cutoff(cutoff)
df_central_bps = k_b0_util.get_central_bps_df(df0)

# %%
df_central_bps.head(20)
# Out:
#     PairID    PairType Big_Category Strand_i  Resid_i Atomname_i  Atomid_i  \
# 0        1  same-P-P-0     backbone  STRAND1        1        O5'         1
# 1        2  same-P-S-0     backbone  STRAND1        1        O5'         1
# 2        3  same-P-S-0     backbone  STRAND1        1        O5'         1
# 5        6  same-P-B-0     backbone  STRAND1        1        O5'         1
# 6        7  same-P-S-0     backbone  STRAND1        1        O5'         1
# 7        8  same-P-S-0     backbone  STRAND1        1        O5'         1
# 9       10  same-P-P-1     backbone  STRAND1        1        O5'         1
# 10      11  same-P-S-0     backbone  STRAND1        1        C5'         2
# 11      12  same-P-S-0     backbone  STRAND1        1        C5'         2
# 14      15  same-P-B-0     backbone  STRAND1        1        C5'         2
# 15      16  same-P-S-0     backbone  STRAND1        1        C5'         2
# ...

# %%
plot_agent = ScatterPlot(rootfolder, cutoff)
# Out:
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/nome/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me1/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me2/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me3/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me12/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me23/bdna+bdna/pd_dfs exists
# /Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/me123/bdna+bdna/pd_dfs exists

# %% [markdown]
# ### Part 2: PP

# %%
category = 'PP'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=300)
plt.show()

# %%
category = 'R'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=300)
plt.show()

# %%
category = 'RB'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=150)
plt.show()

# %%
category = 'PB'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=300)
plt.show()

# %%
category = 'st'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=300)
plt.show()

# %%
category = 'bp'
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(24, 8))
d_axes = plot_agent.plot_main(category, axes)
plt.savefig(f'/Volumes/TOSHIBA_2T/Hsin-Yun/cg_13/fluctmatch/enm/{category}.png', dpi=300)
plt.show()

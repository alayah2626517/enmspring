# %%
import matplotlib.pyplot as plt
from enmspring.spring import Spring
from enmspring import k_b0_util
from enmspring.k_b0_plot import BoxPlot

# %% [markdown]
# ### Part 0: Initialize

# %%
rootfolder = '/Users/alayah361/fluctmatch/enm/cg_21'
cutoff = 4.7
host = '21_allme'
type_na = 'bdna+bdna'
n_bp = 21  ## 13
spring_obj = Spring(rootfolder, host, type_na, n_bp)
# Out:
# /Users/alayah361/fluctmatch/enm/cg_21/21_allme/bdna+bdna/pd_dfs exists

# %% [markdown]
# ### Part 1 : Process Data

# %%
plot_agent = BoxPlot(rootfolder, cutoff)
# Out:
# mkdir /Users/alayah361/fluctmatch/enm/cg_21/nome/bdna+bdna/pd_dfs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-288c22778a44> in <module>
# ----> 1 plot_agent = BoxPlot(rootfolder, cutoff)
#
# ~/codes/enmspring/enmspring/k_b0_plot.py in __init__(self, rootfolder, cutoff)
#     129         self.rootfolder = rootfolder
#     130         self.cutoff = cutoff
# --> 131         self.d_df = self.__initialize_df()
#     132
#     133     def plot_main(self, category, axes, key, nrows, ncols):
#
# ~/codes/enmspring/enmspring/k_b0_plot.py in __initialize_df(self)
#     176         d_temp = dict()
#     177         for host in self.hosts:
# --> 178             spring_obj = Spring(self.rootfolder, host, self.type_na, self.n_bp)
#     179             df0 = spring_obj.read_k_b0_pairtype_df_given_cutoff(self.cutoff)
#     180             d_temp[host] = k_b0_util.get_central_bps_df(df0)
#
# ~/codes/enmspring/enmspring/spring.py in __init__(self, rootfolder, host, type_na, n_bp)
#      22                              '{0}.nohydrogen.avg.crd'.format(self.type_na))
#      23         self.pd_dfs_folder = path.join(self.na_folder, 'pd_dfs')
# ---> 24         self.initialize_folders()
#      25
#      26         self.u = None
#
# ~/codes/enmspring/enmspring/spring.py in initialize_folders(self)
#      37     def initialize_folders(self):
#      38         for folder in [self.pd_dfs_folder]:
# ---> 39             check_dir_exist_and_make(folder)
#      40
#      41     def set_mda_universe(self):
#
# ~/codes/enmspring/enmspring/miscell.py in check_dir_exist_and_make(file_path)
#      34     else:
#      35         print("mkdir {0}".format(file_path))
# ---> 36         mkdir(file_path)
#      37
#      38
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/alayah361/fluctmatch/enm/cg_21/nome/bdna+bdna/pd_dfs'

# %% [markdown]
# ### Part 2: PP

# %%
category = 'PP'
key = 'k'
nrows = 2
ncols = 2
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 10))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()

# %%
category = 'R'
nrows = 1
ncols = 3
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(22, 4))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()

# %%
category = 'RB'
nrows = 2
ncols = 2
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 10))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()

# %%
category = 'PB'
key = 'k'
nrows = 1
ncols = 2
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 4))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()

# %%
category = 'st'
nrows = 1
ncols = 1
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 8))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()

# %%
category = 'bp'
nrows = 1
ncols = 3
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(24, 4))
d_axes = plot_agent.plot_main(category, axes, key, nrows, ncols)
plt.savefig(f'{category}_{key}.png', dpi=150)
plt.show()
